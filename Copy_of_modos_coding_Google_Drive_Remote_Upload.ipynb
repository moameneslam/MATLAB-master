# %% [markdown]
# <a href="https://colab.research.google.com/github/moameneslam/MATLAB-master/blob/master/Copy_of_modos_coding_Google_Drive_Remote_Upload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3329394316.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive', force_remount=True)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     193       raise ValueError('Mountpoint must not be a symlink')
#     194     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# ...

# %%
# !wget -P /content/drive/MyDrive/ https://s251d2.downet.net/download/1767596849/695a11b143a6f/Men.In.Black.II.2002.720p.BluRay.AKWAM.mp4 --no-check-certificate
# Out:
# --2026-01-04 07:08:06--  https://s251d2.downet.net/download/1767596849/695a11b143a6f/Men.In.Black.II.2002.720p.BluRay.AKWAM.mp4
# Resolving s251d2.downet.net (s251d2.downet.net)... 85.121.148.187
# Connecting to s251d2.downet.net (s251d2.downet.net)|85.121.148.187|:443... connected.
# WARNING: cannot verify s251d2.downet.net's certificate, issued by ‘CN=SSL2BUY EMEA RSA Domain Validation Secure Server CA,O=SSL2BUY EMEA LLC,C=AE’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 914903108 (873M) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/Men.In.Black.II.2002.720p.BluRay.AKWAM.mp4’
#
# Men.In.Black.II.200 100%[===================>] 872.52M  12.0MB/s    in 1m 55s
#
# 2026-01-04 07:10:07 (7.56 MB/s) - ‘/content/drive/MyDrive/Men.In.Black.II.2002.720p.BluRay.AKWAM.mp4’ saved [914903108/914903108]
